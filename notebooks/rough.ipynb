# %%
docs = [Document(id='1c545072-3553-472d-a512-ad82bda9910c', metadata={'source': 'Unit-II.pdf', 'creator': 'PyPDF', 'moddate': '2026-08-10T06:33:09+00:00', 'producer': 'iLovePDF', 'total_pages': 27, 'page_label': '10', 'creationdate': '', 'page': 9}, page_content='Predict the value of Y when X = 4.\nTypes of regression: Nonlinear(Polynomial )\nNonlinear Regression is a supervised machine learning technique used to model the \nrelationship between input and output variables when the relationship is curved rather \nthan a straight line.\nGeneral Equation\nThe most common nonlinear regression model is Polynomial Regression.\n𝑌 = 𝛽0 + 𝛽1𝑋 + 𝛽2𝑋2 + 𝛽3𝑋3 + ⋯ + 𝛽𝑛𝑋𝑛\nWhere:\n•Y = Dependent (target) variable \n•X = Independent (input) variable \n•β₀ = Intercept \n•β₁, β₂, ..., βₙ = Regression coefficients \n•n = Degree of the polynomial\nExample :'), Document(id='0072a8c9-e2c8-4947-b53b-666c804afe7f', metadata={'total_pages': 27, 'page_label': '3', 'moddate': '2026-08-10T06:33:09+00:00', 'page': 2, 'source': 'Unit-II.pdf', 'creator': 'PyPDF', 'producer': 'iLovePDF', 'creationdate': ''}, page_content='Dr. Shraddha Pandit Modern COE,Pune\nProf. Pradip Ghorpade VP’s Kamalnayan Bajaj Institute of Engineering & Technology\nDr. Sulochana Sonkamble JSPM Narhe Technical Campus, Pune\nDr. Girisha Bombale SNDCOE & RC,Yeola\nProf. Pradnya Bachhav GGS College of Engineering & Research Centre, Nashik\nProf.Varsha P .Chavan Anantrao Pawar college of Engineering and Research\nMr.Nachiket Kulkarni AutoDesk, Pune\nIntroduction to regression \nRegression:\nRegression is a supervised machine learning technique used to predict a \ncontinuous numerical value by learning the relationship between one or more'), Document(id='70c4efc8-3249-4f64-a779-cf235395cdd8', metadata={'creator': 'PyPDF', 'page': 6, 'page_label': '7', 'creationdate': '', 'total_pages': 27, 'producer': 'iLovePDF', 'source': 'Unit-II.pdf', 'moddate': '2026-08-10T06:33:09+00:00'}, page_content='Y\n↑\n│             ●\n│         ●\n│      ●\n│    ●\n│  ●\n│ ●\n│______________________→ X\n        Curved Fit\nTypes of regression: Linear\n• Linear regression is one of the most fundamental machine learning \nalgorithms used for predicting continuous values. It establishes a \nrelationship between independent variables (ഥ𝒙)and a dependent variable \n(ഥ𝒚) using a straight-line equation.\nEquation of Linear Regression\nThe equation of simple linear regression (with one independent variable) is:\n𝑌 = 𝑚𝑋 + 𝑐\nwhere:\nY = Dependent variable (target)\nX = Independent variable (input feature)')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ...
